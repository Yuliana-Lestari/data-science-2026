# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuliana-Lestari/data-science-2026/blob/main/Latihan_Data_Science_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Latihan 1

# %% [markdown]
# # Pertemuan 1
#
# Nama : Yuliana Lestari
# NIM : 250401020199
# Kelas : IF403

# %%
#Output sederhana
print("Hello Unsia")
# Out:
# Hello Unsia

# %%
#Variable dan tipe data
nama = "Yuliana Lestari" #string
angkatan = 2026 #numerik

print(nama)
print(angkatan)
print(f"Hallo nama saya {nama} dari angkatan {angkatan}")
# Out:
# Yuliana Lestari
# 2026
# Hallo nama saya Yuliana Lestari dari angkatan 2026

# %%
#List
tools= ["Python", "Google Colab", "Jupiter notebook", "Github"]

#Perulangan
for i in tools:
  print(i)
# Out:
# Python
# Google Colab
# Jupiter notebook
# Github

# %%
#Fungsi
def perkenalan(nama, prodi, angkatan):
    return print(f"Hello nama saya {nama} dari prodi {prodi} angkatan {angkatan}")

perkenalan("Yuliana", "Informatika", 2026)
# Out:
# Hello nama saya Yuliana dari prodi Informatika angkatan 2026

# %% [markdown]
# ### Kesimpulan Praktikum (Pertemuan 1)
#
# * **Apa yang dipelajari:**
#   Pada pertemuan pertama ini, saya mempelajari definisi Data Science sebagai bidang multidisiplin yang menggabungkan statistika, ilmu komputer, dan pengetahuan domain (domain knowledge). Selain itu, saya juga mempelajari perbedaan peran antara Data Scientist, Data Analyst, dan Machine Learning Engineer di industri, serta memahami enam fase siklus hidup proyek data menggunakan kerangka CRISP-DM.
#
# * **Temuan utama:**
#   1. Data Science menuntut keseimbangan tiga pilar keahlian utama, bukan hanya kemampuan teknis koding semata.
#   2. Kerangka kerja CRISP-DM menyediakan struktur yang sistematis namun fleksibel dan iteratif dalam mengelola proyek data dari tahap pemahaman bisnis hingga penerapan di lingkungan produksi.
#   3. Berhasil menyiapkan lingkungan kerja awal Data Science dengan membuat akun Google Colab dan GitHub, serta sukses menulis dan menjalankan program Python sederhana secara interaktif.
#
# * **Keterbatasan atau pertanyaan yang muncul:**
#   Meningkatnya pentingnya pemahaman domain bisnis (Domain Knowledge) sebagai salah satu pilar utama Data Science, bagaimana strategi terbaik bagi seorang pemula di bidang Informatika untuk mengasah pemahaman konteks industri tersebut di luar kemampuan teknis pemrograman Python dan statistika?
