# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuliana-Lestari/data-science-2026/blob/main/Latihan_Data_Science_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Latihan 1

# %%
#Output sederhana
print("Hello Unsia")
# Out:
# Hello Unsia

# %%
#Variable dan tipe data
nama = "Yuliana Lestari" #string
angkatan = 2026 #numerik

print(nama)
print(angkatan)
print(f"Hallo nama saya {nama} dari angkatan {angkatan}")
# Out:
# Yuliana Lestari
# 2026
# Hallo nama saya Yuliana Lestari dari angkatan 2026

# %%
#List
tools= ["Python", "Google Colab", "Jupiter notebook", "Github"]

#Perulangan
for i in tools:
  print(i)
# Out:
# Python
# Google Colab
# Jupiter notebook
# Github

# %%
#Fungsi
def perkenalan(nama, prodi, angkatan):
    return print(f"Hello nama saya {nama} dari prodi {prodi} angkatan {angkatan}")

perkenalan("Yuliana", "Informatika", 2026)
# Out:
# Hello nama saya Yuliana dari prodi Informatika angkatan 2026
